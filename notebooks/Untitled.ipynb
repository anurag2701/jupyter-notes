# %%
print("Hello, Jupyter!")
# Out:
# Hello, Jupyter!

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sample data
data = [55, 65, 75, 80, 85, 90, 92, 93, 94, 95, 96, 97, 98, 99, 100, 105, 110]

# Create a box plot
sns.boxplot(data=data)
plt.title("Box Plot of Exam Scores")
plt.show()
